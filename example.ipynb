# %%
# !pip install chdb
# Out:
# ...
#   Obtaining dependency information for chdb from https://files.pythonhosted.org/packages/11/16/9ee9ce1cf9f60ada5e9f4faf2c2fb27842c815294b8acaa0ee31e6b9ce8b/chdb-3.2.0-cp311-cp311-macosx_11_0_arm64.whl.metadata
# ...
#   Obtaining dependency information for pyarrow>=13.0.0 from https://files.pythonhosted.org/packages/47/a2/b7930824181ceadd0c63c1042d01fa4ef63eee233934826a7a2a9af6e463/pyarrow-20.0.0-cp311-cp311-macosx_12_0_arm64.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 MB 6.4 MB/s eta 0:00:0000:0100:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.9/30.9 MB 20.1 MB/s eta 0:00:0000:0100:01
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 25.1
# [notice] To update, run: pip install --upgrade pip

# %%
import chdb
import pandas as pd
query = f"""
SELECT *
FROM file('./items.csv', 'CSVWithNames')
LIMIT 10
"""

# Run the query with chdb
items = chdb.query(query, output_format='DataFrame')
items.head()
# Out:
#                                      id  amount        description  date  \
# 0  af23cd34-9e39-42b1-8400-d3f6018d5bfa    0.00  message generique  None
# 1  059881df-90ad-47d7-8400-d42408b4294a   -3.00                     None
# 2  2d3d88d2-86ec-47e3-8400-d5e2f6c3f7f4   11.99                     None
# 3  ad51964b-0d0b-482a-8400-d67b73fb2677  -36.00                     None
# 4  18b7db0f-b7ef-435e-8400-d802b12d6959 -109.00                     None
#
#                   itemName parent  quantity  taxAmount    taxDescription type  \
# 0  pas bcp de sauce tomate   None       NaN        0.0          TVA 10 %
# 1    remb. tirage et sport   None       NaN        0.0  noTaxDescription
# 2           produit presse   None       NaN        0.0  noTaxDescription
# 3       remboursement jeux   None       NaN        0.0  noTaxDescription
# 4               remb. jeux   None       NaN        0.0  noTaxDescription
#
#    ... keywords         category     subcategory  company      attributes  \
# ...
